# %% [markdown]
# Notebook is copyright &copy; of <a href="https://ajaytech.co">Ajay Tech </a>.

# %% [markdown]
# <div class="jumbotron">
#   <h1 class="display-4"> Strings</h1>
#   <p class="lead">Strings are a sequence of characters that a variable can hold. It is one of the most used data type in Python. In this chapter, we will explore what Strings are and how to work with them.</p>
#   <hr>
#   <h3 class="display-6"> Contents </h3>
#
#   <ul style="list-style-type:none">
#       <li> <a href="#What-are-Strings"> &#10070; What are <b>Strings</b> </li>
#       <li> <a href="#Substrings"> &#10070; Substrings </a> </li>
#       <li> <a href="#String-Indexing"> &#10070; String Indexing </a> </li>
#       <li> <a href="#String-Split"> &#10070; String Split </a> </li>
#       <li> <a href="#String-Strip"> &#10070; String Strip </a> </li>
#       <li> <a href="#String-alpha-numeric-Functions"> &#10070; String alpha numeric Functions </a> </li>
#       <li> <a href="#String-Concatenation"> &#10070; String Concatenation </a> </li>
#       <li> <a href="#String-upper-and-lower-Functions"> &#10070; String <b>upper</b> and <b>lower</b> case Functions </a> </li>
#   </ul>
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="What-are-Strings">
#     <span class="topic"> &#10070;  What are Strings</span>
# </div>

# %% [markdown]
# Strings are a sequence of characters that a variable can hold. For example, the variable name holds a string of characters for the name.

# %%
name = "Ajay"

# %% [markdown]
# Both single quotes and double quotes are ok. So, both of the following versions are acceptable versions of strings in Python.

# %%
name_1 = "Ajay"

#or

name_2 = 'Ajay'

# %% [markdown]
# Python automatically assigns the variable with type string.

# %%
type(name)
# Out:
# str

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Substrings">
#     <span class="topic"> &#10070;  Substrings</span>
# </div>

# %% [markdown]
# String variables have a bunch of <a href="https://docs.python.org/3/library/stdtypes.html#string-methods">inbuilt methods</a> - think of them as helper methods. For example, to find out if the string "Ajay Tech" contains the word "Tech" , use the in-built function **find ( )**

# %%
name = "Ajay Tech"

name.find("Tech")
# Out:
# 5

# %% [markdown]
# **find ( )** returns the index of the start of the sub-string you are looking for. In our case, it is 5. But is it really 5 ? Not unless we start with 0. And just like C or Java, all indexing starts with 0 in Python.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Substring-Indexing">
#     <span class="topic"> &#10070;  Substring Indexing</span>
# </div>

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
# </div>

# %% [markdown]
# With indexing, you can really slice and dice a string any way you want. For example, to extract the first character in the string, just use

# %%
name[0]
# Out:
# 'A'

# %% [markdown]
# Now it should make sense why the substring "tech" starts at 5 and not at 6.

# %% [markdown]
# Now, we are going to look at a couple of string methods that are most used.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="String-Split">
#     <span class="topic"> &#10070;  String Split</span>
# </div>

# %% [markdown]
# Splitting strings is pretty useful. Think if splitting a name into it's first, middle and last names.

# %%
name = "William Bradley Pitt" # BTW, that is Brad Pitt's real name.

# %%
name.split()
# Out:
# ['William', 'Bradley', 'Pitt']

# %% [markdown]
# Using multiple variable assignments, you can split up the string and assign them to multiple variables like below.

# %%
first, middle, last = name.split()

# %%
middle
# Out:
# 'Bradley'

# %% [markdown]
# <kbd>split </kbd> function by default splits the string based on the blank( space ) character. You can split by any other character. For example, if the name was like this,

# %% [markdown]
# <div class="text-center">
# <img src="data:image/png;base64,..."/>
# </div>

# %%
name = "William,Bradley,Pitt"

# %% [markdown]
# you could use ask the <kbd>split</kbd> function to split by **comma (,)** and not by space.

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
# </div>

# %%
first,middle,last = name.split(",")

# %%
middle
# Out:
# 'Bradley'

# %% [markdown]
# We will talk more about functions and arguments in the next section.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="String-Strip">
#     <span class="topic"> &#10070;  String Strip</span>
# </div>

# %% [markdown]
# String strip is another useful function. It is often the case that data is messy. For example, when the user enters their name or address on a web form, they could include additional spaces at the end or at the beginning. This cause inconsistency in comparing strings. For example,

# %%
name_1 = "Ajay"
name_2 = " Ajay " # observe the leading and trailing space

name_1 == name_2
# Out:
# False

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
# </div>

# %%
name_2 = name_2.strip()

# %%
name_1 == name_2
# Out:
# True

# %%
name_1 = "Ajay"
name_2 = " Ajay " # observe the leading and trailing space

name_2.strip()

name_1 == name_2
# Out:
# False

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <span class="topic"> &#9745;  Quiz </span>
# </div>

# %% [markdown]
# <div class="jumbotron">
#     <span class="lead">What is the index of the substring "hot" in the string "Python is a hot language"</span>
#     <blockquote class="blockquote">
#         <p> 10</p>
#     </blockquote>
#     <blockquote class="blockquote">
#         <p>11</p>
#     </blockquote>
#     <blockquote class="blockquote">
#         <p>12</p>
#     </blockquote>
# </div>

# %% [markdown]
# <div class="jumbotron">
#     <span class="lead">What is the output of the code below.</span>
#     <pre>name_1 = "Ajay"
# name_2 = " Ajay " # observe the leading and trailing space
#
# name_2.strip()
#
# print(name_1 == name_2)</pre>
#     <blockquote class="blockquote">
#         <p> True</p>
#     </blockquote>
#     <blockquote class="blockquote">
#         <p>False</p>
#     </blockquote>
# </div>

# %% [markdown]
# <div class="jumbotron">
#     <span class="lead">What is the output of the code below.</span>
#     <pre>name = " Ajay, Tech "
# fname, lname = name.split(",")
# fname = fname.strip()
#
# print(len(fname) == len(lname))</pre>
#     <blockquote class="blockquote">
#         <p> True</p>
#     </blockquote>
#     <blockquote class="blockquote">
#         <p>False</p>
#     </blockquote>
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="String-alpha-numeric-Functions">
#     <span class="topic"> &#10070;  String alpha numeric Functions</span>
# </div>

# %% [markdown]
# Another useful function with Strings in Python is to check if a string is alphanumeric or not. Most websites restrict the user name to be either alphabetic or numeric and nothing else ( no special characters ). How do you check for it ? Use the <kbd>isalnum</kbd> function

# %%
name = " Ajay Tech !!" # contains a non-alpha numeric character "!"
name.isalnum()
# Out:
# False

# %% [markdown]
# Another useful function is to check if the string is just alphabetic or not ( No numerics or special characters ). In this case, use the <kbd>isalpha </kbd> function.

# %%
name = "ajaytech1"  # contains a numeric "1"

# %%
name.isalpha()
# Out:
# True

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="String-Concatenation">
#     <span class="topic"> &#10070;  String Concatenation</span>
# </div>

# %% [markdown]
# Concatenating strings is pretty easy. You don't even need an in-built function for this. Just use the operator **+** . When we visit Object Oriented Python later, we will understand exactly why this works (operator overloading). For now, just think of it as a shortcut to join strings together.

# %%
name_1 = "Ajay"
name_2 = "Tech"

name = name_1 + name_2
print ( name )
# Out:
# AjayTech

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="String-upper-and-lower-case-Functions">
#     <span class="topic"> &#10070;  String upper and lower case Functions</span>
# </div>

# %% [markdown]
# Like we discussed earlier, user data is always messy. For example, when a user enters their name, it could be in a variety of ways
#
# - Init capitals
# - leading and trailing spaces
# - capitals in between etc.

# %% [markdown]
# So, it is common practice to process user data and store it in a standardize way. For example, the name "Ajay tech" would probably be needed to be stored internally as "AJAY TECH" , so that all future data comparisions could be done easily.

# %%
name = "Ajay tech"
name.upper()
# Out:
# 'AJAY TECH'

# %% [markdown]
# It is OK to store it this way, but that is not how you would want to display it back, right ? You would want to display it with Initial capitals - "Ajay Tech" . To do that use the **title ( )** function.

# %%
name_c = name.upper()
name_c
# Out:
# 'AJAY TECH'

# %%
name_c.title()
# Out:
# 'Ajay Tech'

# %% [markdown]
# The point we are trying to make here is that there are a variety of in-built string functions that you can use without having to re-invent the wheel everytime you want some piece of functionality like this. Here are some other useful functions
#
# - <kbd>swapcase</kbd> - swaps upper case to lower and vice-versa
# - <kbd>isupper</kbd> - checks if all the characters in a string are upper case
# - <kbd>islower</kbd> - check if all the characters in the string are lower case
# - <kbd>capitalize</kbd> - Capitalize the first letter and make all the other characters lower case.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="jumbotron">
#     <span class="lead" id="Swap-Variables"> &#x1F44D; <b>Challenge</b> - Reverse a string. For example, if you are given a string "Ajay", you have reverse the characters in the string and return a new string as "yajA.</span>
# </div>

# %%
text = input("enter string > ")

i = len(text)
r_text = ""

while i > 0  :
    r_text = r_text + text[i-1]
    i = i - 1

print ( r_text)
# Out:
# enter string >  Ajay
# yajA

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="jumbotron">
#     <span class="lead" id="Swap-Variables"> &#x1F44D; <b>Challenge</b> - split a user entered string into its words and print each of the word with the initial letter capitalized.</span>
# </div>

# %%
text = input ( "enter string > ")

for word in text.split() :
    print ( word.title())
# Out:
# enter string >  ajay tech is an IT learning company
# Ajay
# Tech
# Is
# An
# It
# Learning
# Company

# %%
# import bootstrap
from IPython.display import HTML
from urllib.request import urlopen
html = urlopen("https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css")
HTML('<style>' + html.read().decode('utf-8') + '</style>')
# bootstrap_icons = urlopen("https://cdn.jsdelivr.net/npm/bootstrap-icons@1.4.0/font/bootstrap-icons.css")
# HTML('<style>' + bootstrap_icons.read().decode('utf-8') + '</style>')
# Out:
# <style>@charset "UTF-8";/*!
#  * Bootstrap v5.0.0-beta3 (https://getbootstrap.com/)
#  * Copyright 2011-2021 The Bootstrap Authors
#  * Copyright 2011-2021 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
# Custom css classes for text highlighting (based on bootstrap.css)

from IPython.core.display import HTML
HTML("""
<style>

kbd { 
    background-color : black !important; 
    font-size : unset !important
}

.yellow { 
    background-color : #fff3cd !important; 
    color : black !important 
}

code { 
    border-radius : .2rem;
    background-color : white !important;
    border : solid 1px black !important
}

.jumbotron {
    background-color : #e9ecef;
    padding : 2rem 1rem;
    border-radius :.3rem
}

.list-group-flush {
    background-color : #e2e3e5 !important;
    padding-left : 0em !important;
}

.list-group-item {
    background-color : #e2e3e5; !important;
}

img {
    box-shadow: 0 4px 8px 0 rgba(0, 0, 0, 0.2), 0 6px 20px 0 rgba(0, 0, 0, 0.19) !important;
}

.bookmark {
    box-shadow : none !important;
    padding-bottom : .5rem !important;
}

.topic {
    font-size : 1.25rem !important;
}

.alert-info {
    background-color : #d1ecf1 !important;
    border-color : #bee5eb !important;
}

</style>
""")
# Out:
# <style>
#
# kbd {
#     background-color : black !important;
#     font-size : unset !important
# }
#
# .yellow {
#     background-color : #fff3cd !important;
#     color : black !important
# }
#
# code {
#     border-radius : .2rem;
#     background-color : white !important;
#     border : solid 1px black !important
# }
#
# .jumbotron {
#     background-color : #e9ecef;
#     padding : 2rem 1rem;
#     border-radius :.3rem
# }
#
# .list-group-flush {
#     background-color : #e2e3e5 !important;
#     padding-left : 0em !important;
# }
#
# .list-group-item {
#     background-color : #e2e3e5; !important;
# }
#
# img {
#     box-shadow: 0 4px 8px 0 rgba(0, 0, 0, 0.2), 0 6px 20px 0 rgba(0, 0, 0, 0.19) !important;
# }
#
# .bookmark {
#     box-shadow : none !important;
#     padding-bottom : .5rem !important;
# }
#
# .topic {
#     font-size : 1.25rem !important;
# }
#
# .alert-info {
#     background-color : #d1ecf1 !important;
#     border-color : #bee5eb !important;
# }
#
# </style>

# %%
# Make the notebook printer friendly by removing the prompts at the left of the code sections.
from IPython.core.display import HTML
HTML("""
<style>

.prompt { display : none;  } 

.jp-InputPrompt {
    color : white !important;
}

.jp-InputArea-prompt {
    color : white !important;
}
.jp-OutputPrompt{
    color : white !important;
}
.jp-OutputArea-prompt{
    color : white !important;
}

</style>
""")
# Out:
# <style>
#
# .prompt { display : none;  }
#
# .jp-InputPrompt {
#     color : white !important;
# }
#
# .jp-InputArea-prompt {
#     color : white !important;
# }
# .jp-OutputPrompt{
#     color : white !important;
# }
# .jp-OutputArea-prompt{
#     color : white !important;
# }
#
# </style>
