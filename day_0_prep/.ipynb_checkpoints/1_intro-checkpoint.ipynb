# %% [markdown]
# Notebook is copyright &copy; of <a href="https://ajaytech.co">Ajay Tech </a>.

# %% [markdown]
# <div class="jumbotron">
#   <h1 class="display-4">Introduction</h1>
#   <p class="lead">This section lays the foundation for learning Python in the coming set of chapters. We focus on the tools and the setup required to learn Python. </p>
#   <hr>
#   <h3 class="display-6"> Contents </h3>
#
#   <ul style="list-style-type:none">
#     <li> <a href="#Why-Python"> &#10070; Why Python </a> </li>
#     <ul style="list-style-type:none">
#         <li> <a href="#Top-Programming-Language"> &#9656; Top Programming Language </a> </li>
#         <li> <a href="#Great-Salaries"> &#9656; Great Salaries </a> </li>
#         <li> <a href="#Extensive-3rd-party-Libraries"> &#9656; Extensive 3rd party Libraries </a> </li>
#         <li> <a href="#Developer-Friendly"> &#9656; Developer Friendly </a> </li>
#      </ul>
#      <li> <a href="#Python-Setup"> &#10070; Python Setup </a> </li>
#        <ul style="list-style-type:none">
#       <li> <a href="#Install-Python-from-Scratch"> &#9656; Install Python from Scratch </a> </li>
#            <li> <a href="#Anaconda"> &#9656; Anaconda - Data Science Specific Distribution </a> </li>
#            <li> <a href="#Virtual"> &#9656; Manage Python Virtual Environment </a> </li>
#       </ul>
#   </ul>
# </div>

# %% [markdown]
# <hr>
# <br>

# %% [markdown]
# <div class="alert alert-secondary" id="Why-Python">
#     <span class="topic"> &#10070; Why Python</span>
# </div>

# %% [markdown]
# In this chapter, we try to understand why Python is the language of choice for Data Science, Machine Learning, Deep Learning, AI, automation and many such new and upcoming areas. Python is an easy to learn programming language. It is designed from the ground-up for readability, portability and easy of use. No wonder the data science and machine learning community has embraced it. There are multiple programming languages used in Data Science, like R, MATLAB, Julia, Scala etc. However, lately, almost all development is happening natively in Python. And most 3rd party libraries are created in Python first. Also, almost all data science or machine learning jobs almost always require you to know Python. No wonder, Python is the language of choice when somebody is beginning to learn Data Science of Machine Learning.

# %% [markdown]
# <div class="alert alert-secondary" id="Top-Programming-Language">
#     <span class="topic">  &#9656; Top Programming Language</span>
# </div>

# %% [markdown]
# Check out this ranking from <a href="https://pypl.github.io/PYPL.html">pypl</a> that measures the popularity of a programming language based on how often language tutorials are searched on google. Python is way ahead of the pack.
# <br>

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
#     </div>

# %% [markdown]
# <br>
# Also, specifically for Data Science and Machine learning, a popular website – KDNuggets has done a poll and found out that Python is getting ahead of other popular languages like R or packages like RapidMiner.
# <br>

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/jpeg;base64,..."/>
# </div>

# %% [markdown]
# <p class="font-weight-light text-center">KDnuggets Analytics/Data Science 2018 Software Poll: top tools in 2018, and their share in the 2016-7 polls</p>

# %% [markdown]
# <blockquote class="blockquote">
#     <p>Python is powerful… and fast; plays well with others; runs everywhere; is friendly & easy to learn; is Open. </p>
#     <figcaption class="blockquote-footer">
#         As cited in <cite title="Source Title">python.org/about/</cite>
#     </figcaption>
# </blockquote>

# %% [markdown]
# You can also look at some of the <a href="https://www.python.org/about/quotes/">quotes</a> from companies on how Python made their lives easy. Since we are just beginning to understand Python, let’s not get ahead of ourselves in trying to understand all that.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Great-Salaries">
#     <span class="topic">  &#9656; Great Salaries</span>
# </div>

# %% [markdown]
# The median salary for Machine Learning engineers in Python is $111K. That is just the median – If you are experienced enough, the sky is the limit. Look at the following snapshot from <a href="https://www.payscale.com/research/US/Job=Machine_Learning_Engineer/Salary/4512ac36/Python">Payscale</a>.

# %% [markdown]
# <br>

# %% [markdown]
# <img class="text-center" src="data:image/png;base64,..."/>

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Extensive-3rd-party-Libraries">
#     <span class="topic">  &#9656; Extensive 3rd Party Libraries</span>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# Once again, if you are from a Java development background, you might contest this. Java is no slouch when it comes to 3rd party libraries. However, they are all limited to web development and other traditional software development areas. When it comes to Data Science, Maching learning and especially deep learning, Python outpaces all languages when it comes to native support for these. The list of top-grade libraries for Maching Learning and Deep Learning is matchless.
#
# - Deep Learning – keras, pytorch,tensorflow, theano etc.
# - Machine Learning – scikit learn, Caffe, Leaf,
#
# The only other language that come this close is probably **R**.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Developer-Friendly">
#     <span class="topic">  &#9656; Developer Friendly</span>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# Python development is 3 to 5 time faster than other comparable languages. If you are interested, here is why Python makes the developer’s life easy

# %% [markdown]
# - A well-known quote, contained in a blockquote element.
#
# Unlike C, C++ or Java, Python is a dynamically typed language. Which means, you would not have to bother with the headache of trying to figure out the data type. That’s why in Python, you would never have to do a

# %%
String name = "Ajay Tech"

# %% [markdown]
# instead, you can just say

# %%
name = "Ajay Tech"

# %% [markdown]
# There are some advantages of static typing, but the easy of use with dynamic typing easily overrules the benefits of static typing.

# %% [markdown]
# - Python is concise

# %% [markdown]
# There are very few traditional programming languages that are as concise as Python. For example, just to say “Hello World”, you would have to do this in Java.

# %%
public class Helloworld
{
    public static void main (String[] args)
    {
        System.out.println("Hello, world");
    }
}

# %% [markdown]
# whereas in Python, you can just say

# %%
print("Hello World")

# %% [markdown]
# - Python is a Glue Language

# %% [markdown]
# When it comes to Data Science or Machine Learning, you would have to work with multiple 3rd party libraries. And Python is a very good glue language. It can connect multiple software components together very easily. For example, if a feature is already implemented in another programming language, say C or C++, it can just be used as-is without having to port it to Python.
#
# Most people compare Python with other high level programming languages like Java and compare Python’s interpreter to Java’s JIT which is faster. Although there is merit to that comparison, in reality the facts are far different. For example, a very popular package for data manipulation is numpy. It is completely written in C, but just wrapped in Python. This makes it almost as fast as C to compute complex n-dimensional array manipulation that might take forever in Java or other high level programming languages.
#
# There are some other examples of glue languages, but Python stands out among them in terms of its simplicity and popularity.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Python-Setup">
#     <span class="topic"> &#10070; Python Setup</span>
# </div>

# %% [markdown]
# <br>
# Installing Python is really simple. We will explore some of the different types of installing Python in this section

# %% [markdown]
# <div class="alert alert-secondary" id="Install-Python-from-Scratch">
#     <span class="topic">  &#9656; Install Python from Scratch</span>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# Installing python is really easy. Just go to <kbd>https://www.python.org</kbd> and hover over the download item in the menu. The latest version of python should be available for download.
#
# <img class="text-center" src="data:image/png;base64,..."/>

# %% [markdown]
# Once you have downloaded the distribution, double click on the executable and you should see a pop-up like this.
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# Make sure you click on the check box “Add Python 3.7 to PATH” . Click on Install now. If you do not have administrative privileges, you might see a different path. If you already have python installed, you might see a pop-up like this. You can choose to upgrade or customize your existing installation .

# %% [markdown]
# <br>

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# Pick your choice of either upgrading from an older version or customizing an existing installation. Now, we are ready to test the Python installation.

# %% [markdown]
# If you have installed python with admin rights on your computer, you should be able to quickly test it by going to the command prompt and typing in python.
#
# - Run the command prompt ( <kbd>Windows + r</kbd> opens the run panel, type in <kbd>cmd</kbd> and hit enter )
# - Enter the python command and you should see the Python shell. If you don’t see this, you might have not selected the “Add Python 3.7 to PATH” checkbox during installation.

# %% [markdown]
# <br>

# %% [markdown]
# <div class="text-center">
#     <img src="data:image/png;base64,..."/>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# type <kbd>exit()</kbd> to exit the command prompt ( the black window above ). That’s it – python is installed.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="alert alert-secondary" id="Anaconda">
#     <span class="topic">  &#9656; Anaconda - Data Science specific Distribution</span>
# </div>

# %% [markdown]
# <br>

# %% [markdown]
# If the goal of learning Python is Data Science specific, you can very well install Python and everything else that you require for Data Science using a package called Anaconda. Anaconda is a full-fledged software distribution for data science that includes python, IDE, packages, package manager and much more.
#
# We do not recommend Anaconda for beginners. Although it has most of the stuff that a data science learner needs, these are all things that you should be able to get on your own. Like
#
# - installing a package manager
# - installing packages
# - installing an IDE of your choice
#
# etc. However, installing Anaconda is not a bad choice either.
#
# Go to https://www.anaconda.com and download the latest distribution. It is going to be a big file – be patient. Once the download is complete, use the installation instructions given in the slideshow below. It is mostly a straight forward process. You can learn more about the Anaconda installation at the link below - https://ajaytech.co/python-setup/#anaconda-data-science-specific-distribution

# %% [markdown]
# <hr>

# %% [markdown]
# <br>

# %% [markdown]
# <div class="alert alert-secondary" id="virtual">
#     <span class="topic">  &#9656; Python Virtual Environment</span>
# </div>

# %% [markdown]
# In real Python working environments, you will have to work with multiple projects. In almost all real projects, some kind of virtual environment is used to separate python installations and packages. We will learn more about this at a later point. However, you can refer to it in the Appendix section or at the following url - https://ajaytech.co/python-virtual-environment/

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
# import bootstrap
from IPython.display import HTML
from urllib.request import urlopen
html = urlopen("https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css")
HTML('<style>' + html.read().decode('utf-8') + '</style>')
# Out:
# <style>@charset "UTF-8";/*!
#  * Bootstrap v5.0.0-beta3 (https://getbootstrap.com/)
#  * Copyright 2011-2021 The Bootstrap Authors
#  * Copyright 2011-2021 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
# Custom css classes for text highlighting (based on bootstrap.css)

from IPython.core.display import HTML
HTML("""
<style>

kbd { 
    background-color : black !important; 
    font-size : unset !important
}

.yellow { 
    background-color : #fff3cd !important; 
    color : black !important 
}

code { 
    border-radius : .2rem;
    background-color : white !important;
    border : solid 1px black !important
}

.jumbotron {
    background-color : #e9ecef;
    padding : 2rem 1rem;
    border-radius :.3rem
}

.list-group-flush {
    background-color : #e2e3e5 !important;
    padding-left : 0em !important;
}

.list-group-item {
    background-color : #e2e3e5; !important;
}

img {
    box-shadow: 0 4px 8px 0 rgba(0, 0, 0, 0.2), 0 6px 20px 0 rgba(0, 0, 0, 0.19) !important;
}

.bookmark {
    box-shadow : none !important;
    padding-bottom : .5rem !important;
}

.topic {
    font-size : 1.25rem !important;
}

.alert-info {
    background-color : #d1ecf1 !important;
    border-color : #bee5eb !important;
}

</style>
""")
# Out:
# <style>
#
# kbd {
#     background-color : black !important;
#     font-size : unset !important
# }
#
# .yellow {
#     background-color : #fff3cd !important;
#     color : black !important
# }
#
# code {
#     border-radius : .2rem;
#     background-color : white !important;
#     border : solid 1px black !important
# }
#
# .jumbotron {
#     background-color : #e9ecef;
#     padding : 2rem 1rem;
#     border-radius :.3rem
# }
#
# .list-group-flush {
#     background-color : #e2e3e5 !important;
#     padding-left : 0em !important;
# }
#
# .list-group-item {
#     background-color : #e2e3e5; !important;
# }
#
# img {
#     box-shadow: 0 4px 8px 0 rgba(0, 0, 0, 0.2), 0 6px 20px 0 rgba(0, 0, 0, 0.19) !important;
# }
#
# .bookmark {
#     box-shadow : none !important;
#     padding-bottom : .5rem !important;
# }
#
# .topic {
#     font-size : 1.25rem !important;
# }
#
# .alert-info {
#     background-color : #d1ecf1 !important;
#     border-color : #bee5eb !important;
# }
#
# </style>

# %%
# Make the notebook printer friendly by removing the prompts at the left of the code sections.
from IPython.core.display import HTML
HTML("""
<style>

.prompt { display : none;  } 

.jp-InputPrompt {
    color : white !important;
}

.jp-InputArea-prompt {
    color : white !important;
}
.jp-OutputPrompt{
    color : white !important;
}
.jp-OutputArea-prompt{
    color : white !important;
}

</style>
""")
# Out:
# <style>
#
# .prompt { display : none;  }
#
# .jp-InputPrompt {
#     color : white !important;
# }
#
# .jp-InputArea-prompt {
#     color : white !important;
# }
# .jp-OutputPrompt{
#     color : white !important;
# }
# .jp-OutputArea-prompt{
#     color : white !important;
# }
#
# </style>
